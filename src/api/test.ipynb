# %%
import mlflow
from mlflow.tracking import MlflowClient

# Remember to set the URI here too
mlflow.set_tracking_uri("http://127.0.0.1:5000")

client = MlflowClient()
for rm in client.search_registered_models():
    print(f"Name: {rm.name}")
# Out:
# Name: CreditRiskModel
